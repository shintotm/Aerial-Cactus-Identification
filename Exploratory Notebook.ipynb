# %% [markdown]
# ## Kaggle competition: Aerial Cactus Identification
# The objective is to create an algorithm that can identify a columnar cactus in aerial imagery.  The dataset has 13136 images that has the columnar cactus and 4364 images without that cactus.
#
# Kaggle competition link: https://www.kaggle.com/c/aerial-cactus-identification

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch import nn
from torch import optim

from torchvision import datasets, transforms, models
from PIL import Image

import pandas as pd

# %%
data_dir = 'data/'

# %%
labels = pd.read_csv('data/train.csv')
labels.head()
# Out:
#                                      id  has_cactus
# 0  0004be2cfeaba1c0361d39e2b000257b.jpg           1
# 1  000c8a36845c0208e833c79c1bffedd1.jpg           1
# 2  000d1e9a533f62e55c289303b072733d.jpg           1
# 3  0011485b40695e9138e92d0b3fb55128.jpg           1
# 4  0014d7a11e90b62848904c1418fc8cf2.jpg           1

# %%
labels.has_cactus.value_counts()
# Out:
# 1    13136
# 0     4364
# Name: has_cactus, dtype: int64

# %% [markdown]
# ## Data distribution

# %%
plt.figure()
plt.pie(labels.groupby('has_cactus').size(), labels=['Has cactus', 'No cactus'],
       autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ### Sample images with cactus

# %%
fig, ax = plt.subplots(1, 5)
for i, filename in enumerate(labels[labels.has_cactus==1]['id'][:5]):
    
    path = 'data/train/'+filename
    ax[i].get_xaxis().set_ticks([])
    ax[i].get_yaxis().set_ticks([])
    ax[i].imshow(plt.imread(path))

# %% [markdown]
# ### Sample images without cactus

# %%
fig, ax = plt.subplots(1, 5)
for i, filename in enumerate(labels[labels.has_cactus==0]['id'][:5]):
    
    path = 'data/train/'+filename
    ax[i].get_xaxis().set_ticks([])
    ax[i].get_yaxis().set_ticks([])
    ax[i].imshow(plt.imread(path))
